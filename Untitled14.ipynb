# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilmadewad27/CV-LAB.2/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow as cv2

# %%
img=cv.imread('/content/cv1.png')
cv2(img)
# Out:
# <PIL.Image.Image image mode=RGB size=212x238>

# %%
#erosion
kernel = np.ones((17,17),np.uint8)
erode=cv.erode(img,kernel ,iterations=1)
cv2(erode)
# Out:
# <PIL.Image.Image image mode=RGB size=212x238>

# %%
#dilution
dilate=cv.dilate(img,kernel,iterations=1)
cv2(dilate)
# Out:
# <PIL.Image.Image image mode=RGB size=212x238>

# %%
#opening
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
plt.imshow(opening, cmap= 'gray')

# %%
#closing
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)
plt.imshow(closing, cmap='gray')

# %%
#gradient
gradient = cv.morphologyEx(img , cv.MORPH_GRADIENT , kernel)
plt.imshow(gradient, cmap= 'gray')

# %%
#tophat
tophat= cv.morphologyEx(img, cv.MORPH_TOPHAT, kernel)
plt.imshow(tophat, cmap= 'gray')

# %%
img2=cv.imread('/content/lab2.png')
cv2(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=466x382>

# %%
#erosion
kernel = np.ones((4,4),np.uint8)
erode1=cv.erode(img2,kernel ,iterations=1)
cv2(erode1)
# Out:
# <PIL.Image.Image image mode=RGB size=466x382>

# %%
#dilution
dilate=cv.dilate(erode1,kernel,iterations=1)
plt.imshow(dilate, cmap= 'gray')

# %%
img3=cv.imread('/content/skll.png')
cv2(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=348x364>

# %%
kernel = np.ones((3,3),np.uint8)
erode=cv.erode(img3,kernel ,iterations=1)
cv2(erode)
# Out:
# <PIL.Image.Image image mode=RGB size=348x364>

# %%
#dilution
dilate=cv.dilate(img3,kernel,iterations=1)
plt.imshow(dilate, cmap= 'gray')

# %%
#gradient
gradient = cv.morphologyEx(img3 , cv.MORPH_GRADIENT , kernel)
plt.imshow(gradient, cmap= 'gray')
